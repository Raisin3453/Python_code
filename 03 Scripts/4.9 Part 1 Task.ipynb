# %% [markdown]
# # 00. Contents

# %% [markdown]
# ### 01. Importing libraries
# ### 02. Importing data frames
# ### 03. Data wrangling
# #### Renaming columns
# #### Changing data types
# ### 04. Data consistency checks
# ### 05. Merging the customer data frame with ords_prods

# %% [markdown]
# # 01. Import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import data frames

# %%
# Creating a path

path = r'/Users/agne/Documents/Studies/Data Analysis/Study Materials/Python/Instacart Basket Analysis 2020 11'

# %%
cust = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))

# %% [markdown]
# # 03. Data wrangling

# %%
cust.shape
# Out:
# (206209, 10)

# %%
cust.head(10)
# Out:
#    user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5   133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6   152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7   168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8    69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9    82820      Shawn     Chung    Male        Virginia   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# ...

# %% [markdown]
# ### Renaming the columns

# %%
cust.rename(columns = {'First Name' : 'name'}, inplace = True)

# %%
cust.rename(columns = {'Surnam' : 'surname'}, inplace = True)

# %%
cust.rename(columns = {'Gender' : 'sex'}, inplace = True)

# %%
cust.rename(columns = {'STATE' : 'state'}, inplace = True)

# %%
cust.rename(columns = {'Age' : 'age'}, inplace = True)

# %%
cust.rename(columns = {'n_dependants' : '#_of_dependants'}, inplace = True)

# %%
cust.head(10)
# Out:
#    user_id      name   surname     sex           state  age date_joined  \
# 0    26711   Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1    33890  Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2    65803   Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3   125935  Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4   130797       Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5   133128   Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6   152052     Chris    Walton    Male         Montana   20    1/1/2017
# 7   168851    Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8    69965    Jeremy      Vang    Male           Texas   47    1/1/2017
# 9    82820     Shawn     Chung    Male        Virginia   26    1/1/2017
#
#    #_of_dependants fam_status  income
# 0                3    married  165665
# 1                0     single   59285
# 2                2    married   99568
# ...

# %% [markdown]
# ### Changing data types

# %%
# Checking data types

cust.dtypes
# Out:
# user_id             int64
# name               object
# surname            object
# sex                object
# state              object
# age                 int64
# date_joined        object
# #_of_dependants     int64
# fam_status         object
# income              int64
# dtype: object

# %%
# Changing data type of used ID to object instead of number

cust['user_id'] = cust['user_id'].astype('object')

# %%
# Checking data types

cust.dtypes
# Out:
# user_id            object
# name               object
# surname            object
# sex                object
# state              object
# age                 int64
# date_joined        object
# #_of_dependants     int64
# fam_status         object
# income              int64
# dtype: object

# %%
# Checking if there are any noticable outliers

cust.describe()
# Out:
#                  age  #_of_dependants         income
# count  206209.000000    206209.000000  206209.000000
# mean       49.501646         1.499823   94632.852548
# std        18.480962         1.118433   42473.786988
# min        18.000000         0.000000   25903.000000
# 25%        33.000000         0.000000   59874.000000
# 50%        49.000000         1.000000   93547.000000
# 75%        66.000000         3.000000  124244.000000
# max        81.000000         3.000000  593901.000000

# %% [markdown]
# No noticable outliers found.

# %%
# Checking if the date_joined column changes through the dataframe

cust.tail()
# Out:
#        user_id     name   surname     sex           state  age date_joined  \
# 206204  168073     Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205   49635   Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206  135902    Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207   81095     Rose   Rollins  Female      California   27    4/1/2020
# 206208   80148  Cynthia     Noble  Female        New York   55    4/1/2020
#
#         #_of_dependants fam_status  income
# 206204                1    married  148828
# 206205                3    married  168639
# 206206                2    married   53374
# 206207                1    married   99799
# 206208                1    married   57095

# %% [markdown]
# # 04. Data Consistency Checks

# %%
# Looking for missing values

cust.isnull().sum()
# Out:
# user_id                0
# name               11259
# surname                0
# sex                    0
# state                  0
# age                    0
# date_joined            0
# #_of_dependants        0
# fam_status             0
# income                 0
# dtype: int64

# %%
# Dropping the column with multiple missing values as it does not add much to the analysis

cust.drop(columns = ['name'], inplace = True)

# %%
# Dropping the column with last names

cust.drop(columns = ['surname'], inplace = True)

# %%
cust.shape
# Out:
# (206209, 8)

# %%
# Looking for duplicates
cust_dups = cust[cust.duplicated()]

# %%
cust_dups
# Out:
# Empty DataFrame
# Columns: [user_id, surname, sex, state, age, date_joined, #_of_dependants, fam_status, income]
# Index: []

# %%
cust_dups.shape
# Out:
# (0, 9)

# %% [markdown]
# No duplicates found.

# %%
# Checking data types for mixed values

cust.dtypes
# Out:
# user_id            object
# surname            object
# sex                object
# state              object
# age                 int64
# date_joined        object
# #_of_dependants     int64
# fam_status         object
# income              int64
# dtype: object

# %% [markdown]
# No mixed values found.

# %% [markdown]
# # 05. Merging the customer data frame with ords_prods

# %%
# Importing ords_prods

ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_agg.pkl'))

# %%
ords_prods.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered  ... _merge    price_range_loc    busiest_days  \
# ...

# %%
ords_prods.dtypes
# Out:
# order_id                     int64
# user_id                      int64
# eval_set                    object
# order_number                 int64
# orders_day_of_week           int64
# order_hour_of_day            int64
# days_since_prior_order     float64
# product_id                   int64
# add_to_cart_order            int64
# reordered                    int64
# product_name                object
# aisle_id                     int64
# department_id                int64
# prices                     float64
# _merge                    category
# price_range_loc             object
# busiest_days                object
# busiest_period_of_day       object
# max_order                    int64
# loyalty_flag                object
# average_spending           float64
# spending_flag               object
# buying_frequency           float64
# frequency_flag              object
# dtype: object

# %%
# dropping an unnecessary column

ords_prods.drop(columns = ['_merge'], inplace = True)

# %%
ords_prods.shape
# Out:
# (32404859, 23)

# %%
# Changing data type of used ID to object instead of number

ords_prods['user_id'] = ords_prods['user_id'].astype('object')

# %%
ords_prods.dtypes
# Out:
# order_id                    int64
# user_id                    object
# eval_set                   object
# order_number                int64
# orders_day_of_week          int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# product_id                  int64
# add_to_cart_order           int64
# reordered                   int64
# product_name               object
# aisle_id                    int64
# department_id               int64
# prices                    float64
# price_range_loc            object
# busiest_days               object
# busiest_period_of_day      object
# max_order                   int64
# loyalty_flag               object
# average_spending          float64
# spending_flag              object
# buying_frequency          float64
# frequency_flag             object
# dtype: object

# %%
# Checking the customer data types

cust.dtypes
# Out:
# user_id            object
# surname            object
# sex                object
# state              object
# age                 int64
# date_joined        object
# #_of_dependants     int64
# fam_status         object
# income              int64
# dtype: object

# %%
# Merging the two data sets

# %%
cust_ords_prods = ords_prods.merge(cust, on = 'user_id')

# %%
# Checking the merge

cust_ords_prods.shape
# Out:
# (32404859, 31)

# %%
#Checking the merge 

cust_ords_prods.head(10)
# Out:
#    order_id user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329       1    prior             1                   2
# 1   2539329       1    prior             1                   2
# 2   2539329       1    prior             1                   2
# 3   2539329       1    prior             1                   2
# 4   2539329       1    prior             1                   2
# 5   2398795       1    prior             2                   3
# 6   2398795       1    prior             2                   3
# 7   2398795       1    prior             2                   3
# 8   2398795       1    prior             2                   3
# 9   2398795       1    prior             2                   3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# ...

# %%
# Exporting data to pickle

cust_ords_prods.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_customers.pkl'))
